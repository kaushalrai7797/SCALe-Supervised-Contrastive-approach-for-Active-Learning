# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
sst2 = np.array([ 0.856651376146789, 0.8853211009174312, 0.8887614678899083, 0.8910550458715596,  0.9013761467889908, 0.9048165137614679, 0.893348623853211, 0.8944954128440367, 0.8956422018348624])
x = np.array(range(1,len(sst2)+1))
plt.plot(x, sst2)
plt.title('SST-2 on Random')
# Out:
# Text(0.5, 1.0, 'SST-2 on Random')

# %%
trec = np.array([[0.554, 0.95, 0.952, 0.968, 0.95], [0.84, 0.964, 0.962, 0.968, 0.964], [0.85, 0.958, 0.956, 0.97, 0.964], [0.85, 0.966, 0.952, 0.97, 0.964], [0.9, 0.96, 0.954, 0.968, 0.964], [0.938, 0.964, 0.952, 0.962, 0.962], [0.942, 0.958, 0.95, 0.97, 0.958], [0.944, 0.952, 0.956, 0.966, 0.96], [0.942, 0.966, 0.962, 0.968, 0.96], [0.954, 0.962, 0.962, 0.968, 0.968], [0.952, 0.962, 0.96, 0.968, 0.968], [0.96, 0.96, 0.968, 0.97, 0.97], [0.97, 0.968, 0.97, 0.968, 0.968], [0.958, 0.966, 0.97, 0.968, 0.966], [0.96, 0.962, 0.968, 0.966, 0.964]])

# %%
x = np.linspace(0, 30, 30)
y = np.sin(x/6*np.pi)
error = np.random.normal(0.1, 0.02, size=y.shape)
y += np.random.normal(0, 0.1, size=y.shape)

plt.plot(x, y, 'k-')
plt.fill_between(x, y-error, y+error)
plt.show()

# %%
yavg = np.mean(trec, axis=1)
x = np.array(range(1,trec.shape[0]+1))
err_min = np.amin(trec, axis=1)
err_max = np.amax(trec, axis=1)

plt.plot(x, yavg, 'k-', color='#3F7F4C')
plt.fill_between(x, err_min, err_max, alpha=0.2, edgecolor='#1B2ACC', facecolor='#089FFF')
plt.show()
# Out:
# /var/folders/nw/pj48g3td4t1_fjsv92n18fvr0000gn/T/ipykernel_87565/3401361193.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x, yavg, 'k-', color='#3F7F4C')

# %%
# fmri = sns.load_dataset("fmri")
# fmri.head()


# fmri['event']

# %%
trec = np.array([[0.612, 0.596], [0.654, 0.794], [0.75, 0.874], [0.826, 0.894], [0.906, 0.92], [0.924, 0.922], [0.938, 0.946], [0.944, 0.952], [0.954, 0.944], [0.956, 0.958], [0.96, 0.968], [0.968, 0.97], [0.97, 0.968], [0.97, 0.972], [0.972, 0.972]])
trecavg = np.mean(trec, axis=1)
x = np.array(range(1,trec.shape[0]+1))
err_min = np.amin(trec, axis=1)
err_max = np.amax(trec, axis=1)

plt.plot(x, trecavg)
plt.title('Trec-6 on Random')
plt.fill_between(x, err_min, err_max, alpha=0.2, edgecolor='#1B2ACC', facecolor='#089FFF')
plt.show()

# %%
x = np.array(range(1,trec.shape[0]+1))

# ST readings
trec_st = np.array([[0.694, 0.564, 0.712, 0.54, 0.55], [0.822, 0.758, 0.8, 0.722, 0.788], [0.874, 0.728, 0.788, 0.782, 0.842], [0.898, 0.894, 0.782, 0.868, 0.904], [0.906, 0.914, 0.874, 0.876, 0.918], [0.922, 0.918, 0.894, 0.892, 0.91], [0.912, 0.92, 0.902, 0.884, 0.928], [0.928, 0.934, 0.912, 0.878, 0.932], [0.948, 0.928, 0.938, 0.914, 0.93], [0.942, 0.936, 0.936, 0.918, 0.942], [0.944, 0.948, 0.922, 0.924, 0.926], [0.948, 0.94, 0.94, 0.932, 0.95], [0.948, 0.952, 0.946, 0.938, 0.948], [0.934, 0.952, 0.93, 0.94, 0.948], [0.944, 0.942, 0.928, 0.944, 0.958]])
trec_st = trec_st*100
trec_st_avg = np.mean(trec_st, axis=1)

# x = np.array(range(1,len(sst2_kat)+1))
trec_kat = np.array([48.69,65.022,66.701,73.097,74.459,74.882,74.286,70.655,69.685,75.897,76.096,76.096,76.892,78.905,77.909])

# 0.954, 0.962, 0.966, 0.974, 0.966, 0.974
# x = np.array(range(1,17,2))

#Supcon readings
trec_supcon = np.array([0.646, 0.708,0.858,0.931,0.94, 0.941, 0.944,0.949,0.949,0.956,0.959,0.962,0.966,0.968,0.974])
trec_supcon = trec_supcon*100


plt.plot(x, trec_kat, color='r', label='Baseline')

plt.plot(x, trec_st_avg, color='b', label='Siamese Bert')
plt.plot(x, trec_supcon, color='black', label='SupCL')


plt.title('Trec6 Results comparison')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nw/pj48g3td4t1_fjsv92n18fvr0000gn/T/ipykernel_13219/4044641929.py in <module>
# ----> 1 x = np.array(range(1,trec.shape[0]+1))
#       2
#       3 # ST readings
#       4 trec_st = np.array([[0.694, 0.564, 0.712, 0.54, 0.55], [0.822, 0.758, 0.8, 0.722, 0.788], [0.874, 0.728, 0.788, 0.782, 0.842], [0.898, 0.894, 0.782, 0.868, 0.904], [0.906, 0.914, 0.874, 0.876, 0.918], [0.922, 0.918, 0.894, 0.892, 0.91], [0.912, 0.92, 0.902, 0.884, 0.928], [0.928, 0.934, 0.912, 0.878, 0.932], [0.948, 0.928, 0.938, 0.914, 0.93], [0.942, 0.936, 0.936, 0.918, 0.942], [0.944, 0.948, 0.922, 0.924, 0.926], [0.948, 0.94, 0.94, 0.932, 0.95], [0.948, 0.952, 0.946, 0.938, 0.948], [0.934, 0.952, 0.93, 0.94, 0.948], [0.944, 0.942, 0.928, 0.944, 0.958]])
#       5 trec_st = trec_st*100
#
# NameError: name 'np' is not defined

# %%
sst2_st = np.array([[0.8555045871559633, 0.8555045871559633, 0.8646788990825688, 0.8497706422018348, 0.8428899082568807], [0.8761467889908257, 0.8876146788990825, 0.8715596330275229, 0.8795871559633027, 0.8795871559633027], [0.8899082568807339, 0.8956422018348624, 0.8841743119266054, 0.8669724770642202, 0.8784403669724771], [0.8887614678899083, 0.8910550458715596, 0.8841743119266054, 0.8887614678899083, 0.8899082568807339], [0.9059633027522935, 0.9002293577981652, 0.8795871559633027, 0.8887614678899083, 0.8841743119266054], [0.9071100917431193, 0.8887614678899083, 0.8899082568807339, 0.8887614678899083, 0.9048165137614679], [0.908256880733945, 0.8990825688073395, 0.9071100917431193, 0.8922018348623854, 0.8990825688073395], [0.8990825688073395, 0.8979357798165137, 0.9105504587155964, 0.893348623853211, 0.8979357798165137], [0.8979357798165137, 0.8990825688073395, 0.9013761467889908, 0.8876146788990825, 0.9048165137614679], [0.8853211009174312, 0.8807339449541285, 0.8979357798165137, 0.8853211009174312, 0.8956422018348624], [0.9071100917431193, 0.9002293577981652, 0.8899082568807339, 0.8990825688073395, 0.9002293577981652], [0.8979357798165137, 0.8956422018348624, 0.9048165137614679, 0.9002293577981652, 0.9036697247706422], [0.9048165137614679, 0.8922018348623854, 0.9059633027522935, 0.893348623853211, 0.9036697247706422], [0.9002293577981652, 0.8944954128440367, 0.9094036697247706, 0.8853211009174312, 0.8944954128440367], [0.9002293577981652, 0.9013761467889908, 0.9048165137614679, 0.8910550458715596, 0.9002293577981652]])
sst2_st = sst2_st*100
sst2_st_avg = np.mean(sst2_st, axis=1)

#Kat readings
sst2_kat = np.array([87.633,90.083,89.362,90.323,90.017,90.288,90.463,90.559,91.174,90.464,90.906,90.459,90.315,90.805,90.784])

sst_supcon = np.array([0.8560223, 0.8860361, 0.901002 , 0.903422 , 0.91229  , 0.91001  ,0.912227 , 0.925344 , 0.9244   , 0.913211 , 0.918    , 0.92888  ,0.93011  , 0.93222  , 0.93422])
sst_supcon = sst_supcon*100
plt.plot(x, sst2_kat, linestyle='dotted', color='b', label='Baseline')
plt.plot(x, sst2_st_avg, linestyle='dashed', color='b', label='Siamese Bert')
plt.plot(x, sst_supcon, color='b', label='SupCL')
plt.title('SST2 Results comparison')
plt.legend()
plt.show()

# %% [raw]
# trec_[[0.694, 0.564, 0.712, 0.54, 0.55], [0.822, 0.758, 0.8, 0.722, 0.788], [0.874, 0.728, 0.788, 0.782, 0.842], [0.898, 0.894, 0.782, 0.868, 0.904], [0.906, 0.914, 0.874, 0.876, 0.918], [0.922, 0.918, 0.894, 0.892, 0.91], [0.912, 0.92, 0.902, 0.884, 0.928], [0.928, 0.934, 0.912, 0.878, 0.932], [0.948, 0.928, 0.938, 0.914, 0.93], [0.942, 0.936, 0.936, 0.918, 0.942], [0.944, 0.948, 0.922, 0.924, 0.926], [0.948, 0.94, 0.94, 0.932, 0.95], [0.948, 0.952, 0.946, 0.938, 0.948], [0.934, 0.952, 0.93, 0.94, 0.948], [0.944, 0.942, 0.928, 0.944, 0.958]]

# %%
trec.shape
# Out:
# (1, 15, 5)

# %%
 trec*100
# Out:
# array([[61.2, 59.6],
#        [65.4, 79.4],
#        [75. , 87.4],
#        [82.6, 89.4],
#        [90.6, 92. ],
#        [92.4, 92.2],
#        [93.8, 94.6],
#        [94.4, 95.2],
#        [95.4, 94.4],
#        [95.6, 95.8],
#        [96. , 96.8],
#        [96.8, 97. ],
#        [97. , 96.8],
#        [97. , 97.2],
#        [97.2, 97.2]])

# %%
len([ 0.856651376146789, 0.8853211009174312, 0.8887614678899083, 0.8910550458715596,  0.9013761467889908, 0.9048165137614679, 0.893348623853211, 0.8944954128440367, 0.8956422018348624])
# Out:
# 9

# %%
len(trec_kat)
# Out:
# 15

# %%
temp = np.array([[0.8560223],[0.8860361],[0.901002],[0.903422],[0.91229],[0.91001],[0.912227],
[0.925344],[0.9244],[0.900211],[0.918000],[0.92888],[0.93011],[0.93222],[0.93422]])

# %%
temp.T[0]
# Out:
# array([0.8560223, 0.8860361, 0.901002 , 0.903422 , 0.91229  , 0.91001  ,
#        0.912227 , 0.925344 , 0.9244   , 0.900211 , 0.918    , 0.92888  ,
#        0.93011  , 0.93222  , 0.93422  ])
